# %%
from skimage.io import imread,imshow,imsave

im = imread('separ.png')

# %%
# %matplotlib inline

from matplotlib import pyplot as plt
plt.axis('off')
plt.title('My Title')

imshow(im)

plt.show()

# %%
imsave('my_new_image.png',im)
